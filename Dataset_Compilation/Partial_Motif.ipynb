# %%
import requests
import pandas as pd
import json
import os
import numpy as np

# ✅ Define file paths
partial_file = "/Users/carmenshero/Desktop/Datasets/Partial_Training.csv"

# ✅ Load Partial_Training dataset
df_partial = pd.read_csv(partial_file, dtype={"ec_numbers": str, "sequence": str}, low_memory=False)

# ✅ Ensure missing values are recognized properly
df_partial["ec_numbers"] = df_partial["ec_numbers"].replace(["nan", np.nan], "")
df_partial["sequence"] = df_partial["sequence"].replace(["nan", np.nan], "")

# ✅ Ensure "Processed_Motifs" column exists
if "Processed_Motifs" not in df_partial.columns:
    df_partial["Processed_Motifs"] = False  # Initialize as unprocessed

print(f"✔ Loaded Partial_Training.csv with {len(df_partial)} entries.")
# Out:
# ✔ Loaded Partial_Training.csv with 5453 entries.

# %%
# ✅ Function to fetch motifs for a given protein sequence
def get_protein_motifs(sequence):
    """Retrieve motifs (PROSITE signatures) based on the protein sequence."""
    
    if sequence == "N/A" or sequence.strip() == "":
        print("⚠️ No sequence available, skipping motif search.")
        return []

    # ✅ Define PROSITE Scan API URL
    url = "https://prosite.expasy.org/cgi-bin/prosite/PSScan.cgi"

    # ✅ Set API request parameters
    params = {
        "seq": sequence,  # Submit the actual protein sequence
        "output": "json"  # Request JSON output
    }

    # ✅ Send request to PROSITE Scan API
    response = requests.get(url, params=params)

    if response.status_code != 200:
        print(f"⚠️ Failed to retrieve motifs for sequence (Error {response.status_code})")
        return []

    data = response.json()
    motifs = []

    # ✅ Extract motifs from response
    for match in data.get("matchset", []):
        motifs.append(match.get("signature_ac"))  # Extract motif signature (e.g., PS00010)

    return motifs

# %%
# ✅ Process each row individually
for index, row in df_partial.iterrows():
    sequence = row["sequence"]  # ✅ Use sequence instead of UniProt ID
    
    # ✅ Skip already processed rows
    if row["Processed_Motifs"]:
        continue  

    # ✅ Skip missing sequences
    if not sequence or pd.isna(sequence) or sequence.strip() == "":
        continue

    try:
        # ✅ Fetch motifs using sequence
        motifs = get_protein_motifs(sequence)

        if not motifs:
            print(f"⚠️ No motifs found for sequence at index {index}. Skipping.")
            continue  # Skip if no motifs were detected

        # ✅ Print motifs found for debugging
        print(f"✔ Found motifs for index {index}: {motifs}")

        # ✅ Ensure motifs are properly encoded
        for motif in motifs:
            if motif in df_partial.columns:
                df_partial.at[index, motif] = 1  # Mark presence
            else:
                print(f"⚠️ Motif '{motif}' not found in columns! Skipping.")

        # ✅ Mark row as processed
        df_partial.at[index, "Processed_Motifs"] = True  

        # ✅ Save after processing each row (ensures progress is retained)
        df_partial.to_csv(partial_file, index=False)

        print(f"✔ Processed sequence {index} and saved progress.")

    except Exception as e:
        print(f"⚠️ Error processing sequence {index}: {e}")
        continue  # Skip to the next row if an error occurs
# Out:
# ⚠️ No motifs found for sequence at index 0. Skipping.
# ⚠️ No motifs found for sequence at index 1. Skipping.
# ⚠️ No motifs found for sequence at index 2. Skipping.
# ⚠️ No motifs found for sequence at index 3. Skipping.
# ⚠️ No motifs found for sequence at index 4. Skipping.
# ⚠️ No motifs found for sequence at index 5. Skipping.
# ✔ Found motifs for index 6: ['PS50404', 'PS50405']
# ✔ Processed sequence 6 and saved progress.
# ✔ Found motifs for index 7: ['PS51679', 'PS00094', 'PS00095']
# ✔ Processed sequence 7 and saved progress.
# ⚠️ No motifs found for sequence at index 8. Skipping.
# ⚠️ No motifs found for sequence at index 9. Skipping.
# ⚠️ No motifs found for sequence at index 10. Skipping.
# ⚠️ No motifs found for sequence at index 11. Skipping.
# ⚠️ No motifs found for sequence at index 12. Skipping.
# ⚠️ No motifs found for sequence at index 13. Skipping.
# ✔ Found motifs for index 14: ['PS00387']
# ✔ Processed sequence 14 and saved progress.
# ⚠️ No motifs found for sequence at index 15. Skipping.
# ⚠️ No motifs found for sequence at index 16. Skipping.
# ✔ Found motifs for index 17: ['PS50862']
# ✔ Processed sequence 17 and saved progress.
# ✔ Found motifs for index 18: ['PS00127']
# ✔ Processed sequence 18 and saved progress.
# ✔ Found motifs for index 19: ['PS00127']
# ✔ Processed sequence 19 and saved progress.
# ✔ Found motifs for index 20: ['PS50404', 'PS50405']
# ✔ Processed sequence 20 and saved progress.
# ⚠️ No motifs found for sequence at index 21. Skipping.
# ✔ Found motifs for index 22: ['PS51421']
# ✔ Processed sequence 22 and saved progress.
# ⚠️ No motifs found for sequence at index 23. Skipping.
# ⚠️ No motifs found for sequence at index 24. Skipping.
# ⚠️ No motifs found for sequence at index 25. Skipping.
# ⚠️ No motifs found for sequence at index 26. Skipping.
# ⚠️ No motifs found for sequence at index 27. Skipping.
# ⚠️ No motifs found for sequence at index 28. Skipping.
# ⚠️ No motifs found for sequence at index 29. Skipping.
# ✔ Found motifs for index 30: ['PS50862']
# ✔ Processed sequence 30 and saved progress.
# ✔ Found motifs for index 31: ['PS51144', 'PS00162']
# ✔ Processed sequence 31 and saved progress.
# ✔ Found motifs for index 32: ['PS50404', 'PS50405']
# ✔ Processed sequence 32 and saved progress.
# ⚠️ No motifs found for sequence at index 33. Skipping.
# ⚠️ No motifs found for sequence at index 34. Skipping.
# ✔ Found motifs for index 35: ['PS51348', 'PS00128']
# ✔ Processed sequence 35 and saved progress.
# ✔ Found motifs for index 36: ['PS51348', 'PS00128']
# ✔ Processed sequence 36 and saved progress.
# ✔ Found motifs for index 37: ['PS51348', 'PS00128']
# ✔ Processed sequence 37 and saved progress.
# ✔ Found motifs for index 38: ['PS51348', 'PS00128']
# ✔ Processed sequence 38 and saved progress.
# ⚠️ No motifs found for sequence at index 39. Skipping.
# ⚠️ No motifs found for sequence at index 40. Skipping.
# ⚠️ No motifs found for sequence at index 41. Skipping.
# ✔ Found motifs for index 42: ['PS50404', 'PS50405']
# ✔ Processed sequence 42 and saved progress.
# ✔ Found motifs for index 43: ['PS00111']
# ✔ Processed sequence 43 and saved progress.
# ⚠️ No motifs found for sequence at index 44. Skipping.
# ⚠️ No motifs found for sequence at index 45. Skipping.
# ⚠️ No motifs found for sequence at index 46. Skipping.
# ⚠️ No motifs found for sequence at index 47. Skipping.
# ⚠️ No motifs found for sequence at index 48. Skipping.
# ⚠️ No motifs found for sequence at index 49. Skipping.
# ⚠️ No motifs found for sequence at index 50. Skipping.
# ⚠️ No motifs found for sequence at index 51. Skipping.
# ⚠️ No motifs found for sequence at index 52. Skipping.
# ⚠️ No motifs found for sequence at index 53. Skipping.
# ✔ Found motifs for index 54: ['PS50404', 'PS50405']
# ✔ Processed sequence 54 and saved progress.
# ⚠️ No motifs found for sequence at index 55. Skipping.
# ⚠️ No motifs found for sequence at index 56. Skipping.
# ⚠️ No motifs found for sequence at index 57. Skipping.
# ⚠️ No motifs found for sequence at index 58. Skipping.
# ⚠️ No motifs found for sequence at index 59. Skipping.
# ⚠️ No motifs found for sequence at index 60. Skipping.
# ⚠️ No motifs found for sequence at index 61. Skipping.
# ⚠️ No motifs found for sequence at index 62. Skipping.
# ⚠️ No motifs found for sequence at index 63. Skipping.
# ⚠️ No motifs found for sequence at index 64. Skipping.
# ⚠️ No motifs found for sequence at index 65. Skipping.
# ⚠️ No motifs found for sequence at index 66. Skipping.
# ⚠️ No motifs found for sequence at index 67. Skipping.
# ⚠️ No motifs found for sequence at index 68. Skipping.
# ⚠️ No motifs found for sequence at index 69. Skipping.
# ⚠️ No motifs found for sequence at index 70. Skipping.
# ⚠️ No motifs found for sequence at index 71. Skipping.
# ⚠️ No motifs found for sequence at index 72. Skipping.
# ⚠️ No motifs found for sequence at index 73. Skipping.
# ⚠️ No motifs found for sequence at index 74. Skipping.
# ✔ Found motifs for index 75: ['PS50404', 'PS50405']
# ✔ Processed sequence 75 and saved progress.
# ✔ Found motifs for index 76: ['PS00111']
# ✔ Processed sequence 76 and saved progress.
# ⚠️ No motifs found for sequence at index 77. Skipping.
# ⚠️ No motifs found for sequence at index 78. Skipping.
# ⚠️ No motifs found for sequence at index 79. Skipping.
# ⚠️ No motifs found for sequence at index 80. Skipping.
# ⚠️ No motifs found for sequence at index 81. Skipping.
# ⚠️ No motifs found for sequence at index 82. Skipping.
# ⚠️ No motifs found for sequence at index 83. Skipping.
# ⚠️ No motifs found for sequence at index 84. Skipping.
# ⚠️ No motifs found for sequence at index 85. Skipping.
# ✔ Found motifs for index 86: ['PS50404', 'PS50405']
# ✔ Processed sequence 86 and saved progress.
# ⚠️ No motifs found for sequence at index 87. Skipping.
# ⚠️ No motifs found for sequence at index 88. Skipping.
# ⚠️ No motifs found for sequence at index 89. Skipping.
# ⚠️ No motifs found for sequence at index 90. Skipping.
# ⚠️ No motifs found for sequence at index 91. Skipping.
# ⚠️ No motifs found for sequence at index 92. Skipping.
# ⚠️ No motifs found for sequence at index 93. Skipping.
# ⚠️ No motifs found for sequence at index 94. Skipping.
# ⚠️ No motifs found for sequence at index 95. Skipping.
# ⚠️ No motifs found for sequence at index 96. Skipping.
# ✔ Found motifs for index 97: ['PS50404', 'PS50405']
# ✔ Processed sequence 97 and saved progress.
# ⚠️ No motifs found for sequence at index 98. Skipping.
# ⚠️ No motifs found for sequence at index 99. Skipping.
# ⚠️ No motifs found for sequence at index 100. Skipping.
# ✔ Found motifs for index 101: ['PS51348', 'PS00128']
# ✔ Processed sequence 101 and saved progress.
# ✔ Found motifs for index 102: ['PS51348', 'PS00128']
# ✔ Processed sequence 102 and saved progress.
# ⚠️ No motifs found for sequence at index 103. Skipping.
# ⚠️ No motifs found for sequence at index 104. Skipping.
# ⚠️ No motifs found for sequence at index 105. Skipping.
# ⚠️ No motifs found for sequence at index 106. Skipping.
# ⚠️ No motifs found for sequence at index 107. Skipping.
# ✔ Found motifs for index 108: ['PS50404', 'PS50405']
# ✔ Processed sequence 108 and saved progress.
# ✔ Found motifs for index 109: ['PS00470']
# ✔ Processed sequence 109 and saved progress.
# ✔ Found motifs for index 110: ['PS50011', 'PS00107', 'PS00108']
# ✔ Processed sequence 110 and saved progress.
# ✔ Found motifs for index 111: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 111 and saved progress.
# ✔ Found motifs for index 112: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 112 and saved progress.
# ✔ Found motifs for index 113: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 113 and saved progress.
# ✔ Found motifs for index 114: ['PS50112', 'PS50113', 'PS50109', 'PS50110', 'PS50894']
# ✔ Processed sequence 114 and saved progress.
# ✔ Found motifs for index 115: ['PS51415']
# ✔ Processed sequence 115 and saved progress.
# ✔ Found motifs for index 116: ['PS51415']
# ✔ Processed sequence 116 and saved progress.
# ✔ Found motifs for index 117: ['PS51415']
# ✔ Processed sequence 117 and saved progress.
# ✔ Found motifs for index 118: ['PS50404', 'PS50405']
# ✔ Processed sequence 118 and saved progress.
# ✔ Found motifs for index 119: ['PS00770']
# ✔ Processed sequence 119 and saved progress.
# ✔ Found motifs for index 120: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 120 and saved progress.
# ✔ Found motifs for index 121: ['PS00697', 'PS50160', 'PS00333']
# ✔ Processed sequence 121 and saved progress.
# ✔ Found motifs for index 122: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 122 and saved progress.
# ✔ Found motifs for index 123: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 123 and saved progress.
# ✔ Found motifs for index 124: ['PS00491']
# ✔ Processed sequence 124 and saved progress.
# ✔ Found motifs for index 125: ['PS50005', 'PS50293', 'PS50005', 'PS50005', 'PS00125']
# ✔ Processed sequence 125 and saved progress.
# ✔ Found motifs for index 126: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 126 and saved progress.
# ✔ Found motifs for index 127: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 127 and saved progress.
# ✔ Found motifs for index 128: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 128 and saved progress.
# ✔ Found motifs for index 129: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 129 and saved progress.
# ✔ Found motifs for index 130: ['PS51693', 'PS51822', 'PS51192', 'PS51194', 'PS50507']
# ✔ Processed sequence 130 and saved progress.
# ✔ Found motifs for index 131: ['PS51693', 'PS51822', 'PS51192', 'PS51194', 'PS50507']
# ✔ Processed sequence 131 and saved progress.
# ✔ Found motifs for index 132: ['PS00097']
# ✔ Processed sequence 132 and saved progress.
# ✔ Found motifs for index 133: ['PS51693', 'PS51822', 'PS51192', 'PS51194', 'PS50507']
# ✔ Processed sequence 133 and saved progress.
# ✔ Found motifs for index 134: ['PS50081', 'PS00479', 'PS50081', 'PS00479', 'PS50004', 'PS50011', 'PS00107', 'PS00108', 'PS51285']
# ✔ Processed sequence 134 and saved progress.
# ✔ Found motifs for index 135: ['PS50064', 'PS00347', 'PS50064', 'PS00347', 'PS52007', 'PS50172', 'PS51977', 'PS51060', 'PS51059']
# ✔ Processed sequence 135 and saved progress.
# ✔ Found motifs for index 136: ['PS00061']
# ✔ Processed sequence 136 and saved progress.
# ✔ Found motifs for index 137: ['PS00118', 'PS00119']
# ✔ Processed sequence 137 and saved progress.
# ✔ Found motifs for index 138: ['PS51420']
# ✔ Processed sequence 138 and saved progress.
# ✔ Found motifs for index 139: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 139 and saved progress.
# ✔ Found motifs for index 140: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 140 and saved progress.
# ✔ Found motifs for index 141: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 141 and saved progress.
# ⚠️ No motifs found for sequence at index 142. Skipping.
# ✔ Found motifs for index 143: ['PS50110', 'PS50122']
# ✔ Processed sequence 143 and saved progress.
# ✔ Found motifs for index 144: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 144 and saved progress.
# ✔ Found motifs for index 145: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 145 and saved progress.
# ✔ Found motifs for index 146: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 146 and saved progress.
# ✔ Found motifs for index 147: ['PS01159', 'PS01164', 'PS01165']
# ✔ Processed sequence 147 and saved progress.
# ✔ Found motifs for index 148: ['PS00127']
# ✔ Processed sequence 148 and saved progress.
# ✔ Found motifs for index 149: ['PS01333', 'PS01334']
# ✔ Processed sequence 149 and saved progress.
# ✔ Found motifs for index 150: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 150 and saved progress.
# ✔ Found motifs for index 151: ['PS52038', 'PS00176']
# ✔ Processed sequence 151 and saved progress.
# ✔ Found motifs for index 152: ['PS50072', 'PS00170']
# ✔ Processed sequence 152 and saved progress.
# ✔ Found motifs for index 153: ['PS52038', 'PS00176']
# ✔ Processed sequence 153 and saved progress.
# ✔ Found motifs for index 154: ['PS52038', 'PS00176']
# ✔ Processed sequence 154 and saved progress.
# ⚠️ No motifs found for sequence at index 155. Skipping.
# ✔ Found motifs for index 156: ['PS51104', 'PS51099', 'PS51094', 'PS00372']
# ✔ Processed sequence 156 and saved progress.
# ✔ Found motifs for index 157: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 157 and saved progress.
# ⚠️ No motifs found for sequence at index 158. Skipping.
# ✔ Found motifs for index 159: ['PS00118', 'PS00119']
# ✔ Processed sequence 159 and saved progress.
# ✔ Found motifs for index 160: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 160 and saved progress.
# ✔ Found motifs for index 161: ['PS00118', 'PS00119']
# ✔ Processed sequence 161 and saved progress.
# ✔ Found motifs for index 162: ['PS00770']
# ✔ Processed sequence 162 and saved progress.
# ✔ Found motifs for index 163: ['PS00659']
# ✔ Processed sequence 163 and saved progress.
# ✔ Found motifs for index 164: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 164 and saved progress.
# ✔ Found motifs for index 165: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 165 and saved progress.
# ✔ Found motifs for index 166: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 166 and saved progress.
# ✔ Found motifs for index 167: ['PS00110']
# ✔ Processed sequence 167 and saved progress.
# ✔ Found motifs for index 168: ['PS00110']
# ✔ Processed sequence 168 and saved progress.
# ✔ Found motifs for index 169: ['PS52038', 'PS00176']
# ✔ Processed sequence 169 and saved progress.
# ✔ Found motifs for index 170: ['PS51144', 'PS00162']
# ✔ Processed sequence 170 and saved progress.
# ✔ Found motifs for index 171: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 171 and saved progress.
# ✔ Found motifs for index 172: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 172 and saved progress.
# ✔ Found motifs for index 173: ['PS51166']
# ✔ Processed sequence 173 and saved progress.
# ✔ Found motifs for index 174: ['PS01057', 'PS01058']
# ✔ Processed sequence 174 and saved progress.
# ✔ Found motifs for index 175: ['PS00110']
# ✔ Processed sequence 175 and saved progress.
# ✔ Found motifs for index 176: ['PS51402', 'PS00438', 'PS00437']
# ✔ Processed sequence 176 and saved progress.
# ⚠️ No motifs found for sequence at index 177. Skipping.
# ✔ Found motifs for index 178: ['PS00766', 'PS00767', 'PS00721', 'PS00722']
# ✔ Processed sequence 178 and saved progress.
# ✔ Found motifs for index 179: ['PS00485']
# ✔ Processed sequence 179 and saved progress.
# ✔ Found motifs for index 180: ['PS00485']
# ✔ Processed sequence 180 and saved progress.
# ⚠️ No motifs found for sequence at index 181. Skipping.
# ✔ Found motifs for index 182: ['PS51420']
# ✔ Processed sequence 182 and saved progress.
# ✔ Found motifs for index 183: ['PS00687', 'PS00070']
# ✔ Processed sequence 183 and saved progress.
# ✔ Found motifs for index 184: ['PS00061']
# ✔ Processed sequence 184 and saved progress.
# ✔ Found motifs for index 185: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 185 and saved progress.
# ⚠️ No motifs found for sequence at index 186. Skipping.
# ✔ Found motifs for index 187: ['PS00687', 'PS00070']
# ✔ Processed sequence 187 and saved progress.
# ✔ Found motifs for index 188: ['PS00167']
# ✔ Processed sequence 188 and saved progress.
# ✔ Found motifs for index 189: ['PS00614']
# ✔ Processed sequence 189 and saved progress.
# ✔ Found motifs for index 190: ['PS50072', 'PS00170']
# ✔ Processed sequence 190 and saved progress.
# ✔ Found motifs for index 191: ['PS00480']
# ✔ Processed sequence 191 and saved progress.
# ✔ Found motifs for index 192: ['PS00167']
# ✔ Processed sequence 192 and saved progress.
# ✔ Found motifs for index 193: ['PS00167']
# ✔ Processed sequence 193 and saved progress.
# ✔ Found motifs for index 194: ['PS00158']
# ✔ Processed sequence 194 and saved progress.
# ✔ Found motifs for index 195: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 195 and saved progress.
# ✔ Found motifs for index 196: ['PS51091', 'PS01253', 'PS50026', 'PS00022', 'PS01186', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 196 and saved progress.
# ✔ Found motifs for index 197: ['PS51091', 'PS01253', 'PS50026', 'PS00022', 'PS01186', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 197 and saved progress.
# ⚠️ No motifs found for sequence at index 198. Skipping.
# ⚠️ No motifs found for sequence at index 199. Skipping.
# ⚠️ No motifs found for sequence at index 200. Skipping.
# ⚠️ No motifs found for sequence at index 201. Skipping.
# ⚠️ No motifs found for sequence at index 202. Skipping.
# ✔ Found motifs for index 203: ['PS00127']
# ✔ Processed sequence 203 and saved progress.
# ✔ Found motifs for index 204: ['PS00127']
# ✔ Processed sequence 204 and saved progress.
# ✔ Found motifs for index 205: ['PS00167']
# ✔ Processed sequence 205 and saved progress.
# ⚠️ No motifs found for sequence at index 206. Skipping.
# ✔ Found motifs for index 207: ['PS00110']
# ✔ Processed sequence 207 and saved progress.
# ✔ Found motifs for index 208: ['PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 208 and saved progress.
# ✔ Found motifs for index 209: ['PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 209 and saved progress.
# ✔ Found motifs for index 210: ['PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 210 and saved progress.
# ✔ Found motifs for index 211: ['PS50055', 'PS50056', 'PS00383']
# ✔ Processed sequence 211 and saved progress.
# ✔ Found motifs for index 212: ['PS00064']
# ✔ Processed sequence 212 and saved progress.
# ✔ Found motifs for index 213: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 213 and saved progress.
# ✔ Found motifs for index 214: ['PS01232']
# ✔ Processed sequence 214 and saved progress.
# ✔ Found motifs for index 215: ['PS00648']
# ✔ Processed sequence 215 and saved progress.
# ✔ Found motifs for index 216: ['PS51746', 'PS01032']
# ✔ Processed sequence 216 and saved progress.
# ✔ Found motifs for index 217: ['PS00139', 'PS00639']
# ✔ Processed sequence 217 and saved progress.
# ✔ Found motifs for index 218: ['PS00059']
# ✔ Processed sequence 218 and saved progress.
# ✔ Found motifs for index 219: ['PS00059']
# ✔ Processed sequence 219 and saved progress.
# ⚠️ No motifs found for sequence at index 220. Skipping.
# ✔ Found motifs for index 221: ['PS00738', 'PS00739']
# ✔ Processed sequence 221 and saved progress.
# ✔ Found motifs for index 222: ['PS00567']
# ✔ Processed sequence 222 and saved progress.
# ✔ Found motifs for index 223: ['PS00071']
# ✔ Processed sequence 223 and saved progress.
# ✔ Found motifs for index 224: ['PS00743', 'PS00744']
# ✔ Processed sequence 224 and saved progress.
# ✔ Found motifs for index 225: ['PS50059']
# ✔ Processed sequence 225 and saved progress.
# ✔ Found motifs for index 226: ['PS00798']
# ✔ Processed sequence 226 and saved progress.
# ✔ Found motifs for index 227: ['PS50001', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 227 and saved progress.
# ⚠️ No motifs found for sequence at index 228. Skipping.
# ✔ Found motifs for index 229: ['PS00546', 'PS00142', 'PS51642', 'PS00024', 'PS51642', 'PS51642', 'PS51642']
# ✔ Processed sequence 229 and saved progress.
# ✔ Found motifs for index 230: ['PS00546', 'PS00142', 'PS51642', 'PS00024', 'PS51642', 'PS51642', 'PS51642']
# ✔ Processed sequence 230 and saved progress.
# ✔ Found motifs for index 231: ['PS00142']
# ✔ Processed sequence 231 and saved progress.
# ✔ Found motifs for index 232: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 232 and saved progress.
# ✔ Found motifs for index 233: ['PS50886']
# ✔ Processed sequence 233 and saved progress.
# ✔ Found motifs for index 234: ['PS00102']
# ✔ Processed sequence 234 and saved progress.
# ✔ Found motifs for index 235: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 235 and saved progress.
# ✔ Found motifs for index 236: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 236 and saved progress.
# ✔ Found motifs for index 237: ['PS51384']
# ✔ Processed sequence 237 and saved progress.
# ✔ Found motifs for index 238: ['PS00859', 'PS00860']
# ✔ Processed sequence 238 and saved progress.
# ✔ Found motifs for index 239: ['PS00743', 'PS00744']
# ✔ Processed sequence 239 and saved progress.
# ✔ Found motifs for index 240: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 240 and saved progress.
# ✔ Found motifs for index 241: ['PS00103']
# ✔ Processed sequence 241 and saved progress.
# ✔ Found motifs for index 242: ['PS00103']
# ✔ Processed sequence 242 and saved progress.
# ✔ Found motifs for index 243: ['PS00103']
# ✔ Processed sequence 243 and saved progress.
# ✔ Found motifs for index 244: ['PS00103']
# ✔ Processed sequence 244 and saved progress.
# ✔ Found motifs for index 245: ['PS00859', 'PS00860']
# ✔ Processed sequence 245 and saved progress.
# ✔ Found motifs for index 246: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 246 and saved progress.
# ✔ Found motifs for index 247: ['PS01240']
# ✔ Processed sequence 247 and saved progress.
# ✔ Found motifs for index 248: ['PS01240']
# ✔ Processed sequence 248 and saved progress.
# ✔ Found motifs for index 249: ['PS01240']
# ✔ Processed sequence 249 and saved progress.
# ✔ Found motifs for index 250: ['PS01240']
# ✔ Processed sequence 250 and saved progress.
# ✔ Found motifs for index 251: ['PS01240']
# ✔ Processed sequence 251 and saved progress.
# ✔ Found motifs for index 252: ['PS01240']
# ✔ Processed sequence 252 and saved progress.
# ✔ Found motifs for index 253: ['PS50011', 'PS00107', 'PS01351']
# ✔ Processed sequence 253 and saved progress.
# ✔ Found motifs for index 254: ['PS51257', 'PS50975', 'PS00866', 'PS00867', 'PS50975', 'PS00866', 'PS00867', 'PS51855']
# ✔ Processed sequence 254 and saved progress.
# ⚠️ No motifs found for sequence at index 255. Skipping.
# ⚠️ No motifs found for sequence at index 256. Skipping.
# ✔ Found motifs for index 257: ['PS00157']
# ✔ Processed sequence 257 and saved progress.
# ✔ Found motifs for index 258: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 258 and saved progress.
# ✔ Found motifs for index 259: ['PS51421']
# ✔ Processed sequence 259 and saved progress.
# ✔ Found motifs for index 260: ['PS00105']
# ✔ Processed sequence 260 and saved progress.
# ✔ Found motifs for index 261: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 261 and saved progress.
# ✔ Found motifs for index 262: ['PS00105']
# ✔ Processed sequence 262 and saved progress.
# ✔ Found motifs for index 263: ['PS00105']
# ✔ Processed sequence 263 and saved progress.
# ✔ Found motifs for index 264: ['PS50055', 'PS50056', 'PS00383']
# ✔ Processed sequence 264 and saved progress.
# ✔ Found motifs for index 265: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 265 and saved progress.
# ✔ Found motifs for index 266: ['PS52040']
# ✔ Processed sequence 266 and saved progress.
# ✔ Found motifs for index 267: ['PS50125', 'PS00452', 'PS50125', 'PS00452']
# ✔ Processed sequence 267 and saved progress.
# ✔ Found motifs for index 268: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 268 and saved progress.
# ✔ Found motifs for index 269: ['PS00102']
# ✔ Processed sequence 269 and saved progress.
# ✔ Found motifs for index 270: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 270 and saved progress.
# ✔ Found motifs for index 271: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 271 and saved progress.
# ✔ Found motifs for index 272: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 272 and saved progress.
# ✔ Found motifs for index 273: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 273 and saved progress.
# ✔ Found motifs for index 274: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 274 and saved progress.
# ✔ Found motifs for index 275: ['PS00275', 'PS50231', 'PS50231']
# ✔ Processed sequence 275 and saved progress.
# ✔ Found motifs for index 276: ['PS00820', 'PS51166']
# ✔ Processed sequence 276 and saved progress.
# ✔ Found motifs for index 277: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 277 and saved progress.
# ✔ Found motifs for index 278: ['PS00131', 'PS00560']
# ✔ Processed sequence 278 and saved progress.
# ✔ Found motifs for index 279: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 279 and saved progress.
# ✔ Found motifs for index 280: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 280 and saved progress.
# ✔ Found motifs for index 281: ['PS00941', 'PS00122']
# ✔ Processed sequence 281 and saved progress.
# ✔ Found motifs for index 282: ['PS00941', 'PS00122']
# ✔ Processed sequence 282 and saved progress.
# ✔ Found motifs for index 283: ['PS00097']
# ✔ Processed sequence 283 and saved progress.
# ✔ Found motifs for index 284: ['PS00099', 'PS00450', 'PS01244']
# ✔ Processed sequence 284 and saved progress.
# ✔ Found motifs for index 285: ['PS00820', 'PS51166']
# ✔ Processed sequence 285 and saved progress.
# ✔ Found motifs for index 286: ['PS50972', 'PS00792', 'PS00793']
# ✔ Processed sequence 286 and saved progress.
# ✔ Found motifs for index 287: ['PS00687', 'PS00070']
# ✔ Processed sequence 287 and saved progress.
# ✔ Found motifs for index 288: ['PS50972', 'PS00792', 'PS00793']
# ✔ Processed sequence 288 and saved progress.
# ✔ Found motifs for index 289: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 289 and saved progress.
# ✔ Found motifs for index 290: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 290 and saved progress.
# ✔ Found motifs for index 291: ['PS00059']
# ✔ Processed sequence 291 and saved progress.
# ✔ Found motifs for index 292: ['PS00059']
# ✔ Processed sequence 292 and saved progress.
# ✔ Found motifs for index 293: ['PS00485']
# ✔ Processed sequence 293 and saved progress.
# ✔ Found motifs for index 294: ['PS01266', 'PS00513']
# ✔ Processed sequence 294 and saved progress.
# ✔ Found motifs for index 295: ['PS00059']
# ✔ Processed sequence 295 and saved progress.
# ✔ Found motifs for index 296: ['PS00059']
# ✔ Processed sequence 296 and saved progress.
# ✔ Found motifs for index 297: ['PS01266', 'PS00513']
# ✔ Processed sequence 297 and saved progress.
# ✔ Found motifs for index 298: ['PS50862']
# ✔ Processed sequence 298 and saved progress.
# ✔ Found motifs for index 299: ['PS01124', 'PS00041', 'PS00041', 'PS00374']
# ✔ Processed sequence 299 and saved progress.
# ✔ Found motifs for index 300: ['PS00158']
# ✔ Processed sequence 300 and saved progress.
# ✔ Found motifs for index 301: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 301 and saved progress.
# ✔ Found motifs for index 302: ['PS50862']
# ✔ Processed sequence 302 and saved progress.
# ✔ Found motifs for index 303: ['PS00061']
# ✔ Processed sequence 303 and saved progress.
# ✔ Found motifs for index 304: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 304 and saved progress.
# ✔ Found motifs for index 305: ['PS00118', 'PS00119']
# ✔ Processed sequence 305 and saved progress.
# ✔ Found motifs for index 306: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 306 and saved progress.
# ✔ Found motifs for index 307: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 307 and saved progress.
# ✔ Found motifs for index 308: ['PS00139', 'PS00639', 'PS00640']
# ✔ Processed sequence 308 and saved progress.
# ✔ Found motifs for index 309: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 309 and saved progress.
# ✔ Found motifs for index 310: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 310 and saved progress.
# ✔ Found motifs for index 311: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 311 and saved progress.
# ✔ Found motifs for index 312: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 312 and saved progress.
# ✔ Found motifs for index 313: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 313 and saved progress.
# ✔ Found motifs for index 314: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 314 and saved progress.
# ✔ Found motifs for index 315: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 315 and saved progress.
# ✔ Found motifs for index 316: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 316 and saved progress.
# ✔ Found motifs for index 317: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 317 and saved progress.
# ✔ Found motifs for index 318: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 318 and saved progress.
# ✔ Found motifs for index 319: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 319 and saved progress.
# ⚠️ No motifs found for sequence at index 320. Skipping.
# ✔ Found motifs for index 321: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 321 and saved progress.
# ✔ Found motifs for index 322: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 322 and saved progress.
# ✔ Found motifs for index 323: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 323 and saved progress.
# ✔ Found motifs for index 324: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 324 and saved progress.
# ✔ Found motifs for index 325: ['PS50830', 'PS01123', 'PS01284']
# ✔ Processed sequence 325 and saved progress.
# ✔ Found motifs for index 326: ['PS00142', 'PS00330']
# ✔ Processed sequence 326 and saved progress.
# ✔ Found motifs for index 327: ['PS51747', 'PS00903', 'PS51747']
# ✔ Processed sequence 327 and saved progress.
# ✔ Found motifs for index 328: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 328 and saved progress.
# ✔ Found motifs for index 329: ['PS50123']
# ✔ Processed sequence 329 and saved progress.
# ✔ Found motifs for index 330: ['PS00142']
# ✔ Processed sequence 330 and saved progress.
# ✔ Found motifs for index 331: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 331 and saved progress.
# ✔ Found motifs for index 332: ['PS00127']
# ✔ Processed sequence 332 and saved progress.
# ✔ Found motifs for index 333: ['PS00127']
# ✔ Processed sequence 333 and saved progress.
# ✔ Found motifs for index 334: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 334 and saved progress.
# ✔ Found motifs for index 335: ['PS00574']
# ✔ Processed sequence 335 and saved progress.
# ✔ Found motifs for index 336: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 336 and saved progress.
# ✔ Found motifs for index 337: ['PS00368']
# ✔ Processed sequence 337 and saved progress.
# ✔ Found motifs for index 338: ['PS00127']
# ✔ Processed sequence 338 and saved progress.
# ✔ Found motifs for index 339: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 339 and saved progress.
# ✔ Found motifs for index 340: ['PS00098', 'PS00737', 'PS00099']
# ✔ Processed sequence 340 and saved progress.
# ✔ Found motifs for index 341: ['PS51440', 'PS00171']
# ✔ Processed sequence 341 and saved progress.
# ✔ Found motifs for index 342: ['PS00687', 'PS00070']
# ✔ Processed sequence 342 and saved progress.
# ✔ Found motifs for index 343: ['PS00820', 'PS51166']
# ✔ Processed sequence 343 and saved progress.
# ✔ Found motifs for index 344: ['PS00059']
# ✔ Processed sequence 344 and saved progress.
# ✔ Found motifs for index 345: ['PS51421']
# ✔ Processed sequence 345 and saved progress.
# ✔ Found motifs for index 346: ['PS50404', 'PS50405']
# ✔ Processed sequence 346 and saved progress.
# ✔ Found motifs for index 347: ['PS50835', 'PS50835', 'PS50835', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 347 and saved progress.
# ✔ Found motifs for index 348: ['PS51732', 'PS00144', 'PS00917']
# ✔ Processed sequence 348 and saved progress.
# ✔ Found motifs for index 349: ['PS00155', 'PS00931']
# ✔ Processed sequence 349 and saved progress.
# ✔ Found motifs for index 350: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 350 and saved progress.
# ✔ Found motifs for index 351: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 351 and saved progress.
# ✔ Found motifs for index 352: ['PS00798', 'PS00062', 'PS00063']
# ✔ Processed sequence 352 and saved progress.
# ✔ Found motifs for index 353: ['PS00533']
# ✔ Processed sequence 353 and saved progress.
# ✔ Found motifs for index 354: ['PS51346', 'PS00384']
# ✔ Processed sequence 354 and saved progress.
# ✔ Found motifs for index 355: ['PS00275']
# ✔ Processed sequence 355 and saved progress.
# ✔ Found motifs for index 356: ['PS00275']
# ✔ Processed sequence 356 and saved progress.
# ✔ Found motifs for index 357: ['PS00275']
# ✔ Processed sequence 357 and saved progress.
# ✔ Found motifs for index 358: ['PS00105']
# ✔ Processed sequence 358 and saved progress.
# ✔ Found motifs for index 359: ['PS00105']
# ✔ Processed sequence 359 and saved progress.
# ✔ Found motifs for index 360: ['PS00105']
# ✔ Processed sequence 360 and saved progress.
# ✔ Found motifs for index 361: ['PS00061']
# ✔ Processed sequence 361 and saved progress.
# ✔ Found motifs for index 362: ['PS00061']
# ✔ Processed sequence 362 and saved progress.
# ⚠️ No motifs found for sequence at index 363. Skipping.
# ✔ Found motifs for index 364: ['PS00102']
# ✔ Processed sequence 364 and saved progress.
# ✔ Found motifs for index 365: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 365 and saved progress.
# ✔ Found motifs for index 366: ['PS51387']
# ✔ Processed sequence 366 and saved progress.
# ✔ Found motifs for index 367: ['PS51387']
# ✔ Processed sequence 367 and saved progress.
# ✔ Found motifs for index 368: ['PS00105']
# ✔ Processed sequence 368 and saved progress.
# ✔ Found motifs for index 369: ['PS00105']
# ✔ Processed sequence 369 and saved progress.
# ✔ Found motifs for index 370: ['PS51387']
# ✔ Processed sequence 370 and saved progress.
# ✔ Found motifs for index 371: ['PS00470']
# ✔ Processed sequence 371 and saved progress.
# ✔ Found motifs for index 372: ['PS00470']
# ✔ Processed sequence 372 and saved progress.
# ⚠️ No motifs found for sequence at index 373. Skipping.
# ⚠️ No motifs found for sequence at index 374. Skipping.
# ⚠️ No motifs found for sequence at index 375. Skipping.
# ⚠️ No motifs found for sequence at index 376. Skipping.
# ✔ Found motifs for index 377: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 377 and saved progress.
# ✔ Found motifs for index 378: ['PS51330', 'PS00075']
# ✔ Processed sequence 378 and saved progress.
# ✔ Found motifs for index 379: ['PS00105']
# ✔ Processed sequence 379 and saved progress.
# ✔ Found motifs for index 380: ['PS00105']
# ✔ Processed sequence 380 and saved progress.
# ✔ Found motifs for index 381: ['PS00105']
# ✔ Processed sequence 381 and saved progress.
# ✔ Found motifs for index 382: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 382 and saved progress.
# ✔ Found motifs for index 383: ['PS51257', 'PS00139', 'PS00639', 'PS00640']
# ✔ Processed sequence 383 and saved progress.
# ✔ Found motifs for index 384: ['PS00091']
# ✔ Processed sequence 384 and saved progress.
# ⚠️ No motifs found for sequence at index 385. Skipping.
# ✔ Found motifs for index 386: ['PS00659']
# ✔ Processed sequence 386 and saved progress.
# ✔ Found motifs for index 387: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 387 and saved progress.
# ✔ Found motifs for index 388: ['PS50972', 'PS00792', 'PS00793']
# ✔ Processed sequence 388 and saved progress.
# ✔ Found motifs for index 389: ['PS50972', 'PS00792', 'PS00793']
# ✔ Processed sequence 389 and saved progress.
# ✔ Found motifs for index 390: ['PS50880', 'PS00177']
# ✔ Processed sequence 390 and saved progress.
# ✔ Found motifs for index 391: ['PS00480']
# ✔ Processed sequence 391 and saved progress.
# ✔ Found motifs for index 392: ['PS00123']
# ✔ Processed sequence 392 and saved progress.
# ✔ Found motifs for index 393: ['PS00123']
# ✔ Processed sequence 393 and saved progress.
# ✔ Found motifs for index 394: ['PS00123']
# ✔ Processed sequence 394 and saved progress.
# ✔ Found motifs for index 395: ['PS00123']
# ✔ Processed sequence 395 and saved progress.
# ✔ Found motifs for index 396: ['PS51420']
# ✔ Processed sequence 396 and saved progress.
# ✔ Found motifs for index 397: ['PS51762', 'PS01034']
# ✔ Processed sequence 397 and saved progress.
# ✔ Found motifs for index 398: ['PS00091']
# ✔ Processed sequence 398 and saved progress.
# ⚠️ No motifs found for sequence at index 399. Skipping.
# ✔ Found motifs for index 400: ['PS51762', 'PS01034']
# ✔ Processed sequence 400 and saved progress.
# ⚠️ No motifs found for sequence at index 401. Skipping.
# ⚠️ No motifs found for sequence at index 402. Skipping.
# ✔ Found motifs for index 403: ['PS00105']
# ✔ Processed sequence 403 and saved progress.
# ✔ Found motifs for index 404: ['PS00105']
# ✔ Processed sequence 404 and saved progress.
# ✔ Found motifs for index 405: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 405 and saved progress.
# ✔ Found motifs for index 406: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 406 and saved progress.
# ✔ Found motifs for index 407: ['PS50972', 'PS00792', 'PS00793']
# ✔ Processed sequence 407 and saved progress.
# ⚠️ No motifs found for sequence at index 408. Skipping.
# ✔ Found motifs for index 409: ['PS00534']
# ✔ Processed sequence 409 and saved progress.
# ✔ Found motifs for index 410: ['PS00113']
# ✔ Processed sequence 410 and saved progress.
# ✔ Found motifs for index 411: ['PS50072', 'PS00170']
# ✔ Processed sequence 411 and saved progress.
# ✔ Found motifs for index 412: ['PS51371', 'PS51371', 'PS00487']
# ✔ Processed sequence 412 and saved progress.
# ✔ Found motifs for index 413: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 413 and saved progress.
# ✔ Found motifs for index 414: ['PS00105']
# ✔ Processed sequence 414 and saved progress.
# ✔ Found motifs for index 415: ['PS00105']
# ✔ Processed sequence 415 and saved progress.
# ✔ Found motifs for index 416: ['PS00105']
# ✔ Processed sequence 416 and saved progress.
# ✔ Found motifs for index 417: ['PS00086']
# ✔ Processed sequence 417 and saved progress.
# ✔ Found motifs for index 418: ['PS00113']
# ✔ Processed sequence 418 and saved progress.
# ✔ Found motifs for index 419: ['PS51348', 'PS00128']
# ✔ Processed sequence 419 and saved progress.
# ✔ Found motifs for index 420: ['PS00142', 'PS00330']
# ✔ Processed sequence 420 and saved progress.
# ✔ Found motifs for index 421: ['PS00097']
# ✔ Processed sequence 421 and saved progress.
# ✔ Found motifs for index 422: ['PS00941', 'PS00122']
# ✔ Processed sequence 422 and saved progress.
# ✔ Found motifs for index 423: ['PS51435', 'PS00726', 'PS00727', 'PS00728']
# ✔ Processed sequence 423 and saved progress.
# ✔ Found motifs for index 424: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 424 and saved progress.
# ✔ Found motifs for index 425: ['PS00113']
# ✔ Processed sequence 425 and saved progress.
# ✔ Found motifs for index 426: ['PS00130']
# ✔ Processed sequence 426 and saved progress.
# ✔ Found motifs for index 427: ['PS51218', 'PS51874', 'PS50507']
# ✔ Processed sequence 427 and saved progress.
# ✔ Found motifs for index 428: ['PS51349', 'PS00557']
# ✔ Processed sequence 428 and saved progress.
# ✔ Found motifs for index 429: ['PS51349', 'PS00557']
# ✔ Processed sequence 429 and saved progress.
# ✔ Found motifs for index 430: ['PS00158']
# ✔ Processed sequence 430 and saved progress.
# ✔ Found motifs for index 431: ['PS00076']
# ✔ Processed sequence 431 and saved progress.
# ✔ Found motifs for index 432: ['PS00123']
# ✔ Processed sequence 432 and saved progress.
# ✔ Found motifs for index 433: ['PS00123']
# ✔ Processed sequence 433 and saved progress.
# ✔ Found motifs for index 434: ['PS00123']
# ✔ Processed sequence 434 and saved progress.
# ✔ Found motifs for index 435: ['PS00123']
# ✔ Processed sequence 435 and saved progress.
# ✔ Found motifs for index 436: ['PS51747', 'PS00903', 'PS51747']
# ✔ Processed sequence 436 and saved progress.
# ✔ Found motifs for index 437: ['PS51257', 'PS00146']
# ✔ Processed sequence 437 and saved progress.
# ✔ Found motifs for index 438: ['PS52040', 'PS50817', 'PS50818']
# ✔ Processed sequence 438 and saved progress.
# ✔ Found motifs for index 439: ['PS51144', 'PS00162']
# ✔ Processed sequence 439 and saved progress.
# ⚠️ No motifs found for sequence at index 440. Skipping.
# ✔ Found motifs for index 441: ['PS00105']
# ✔ Processed sequence 441 and saved progress.
# ✔ Found motifs for index 442: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 442 and saved progress.
# ✔ Found motifs for index 443: ['PS00099', 'PS00450', 'PS01244']
# ✔ Processed sequence 443 and saved progress.
# ✔ Found motifs for index 444: ['PS00099', 'PS00450', 'PS01244']
# ✔ Processed sequence 444 and saved progress.
# ✔ Found motifs for index 445: ['PS51440', 'PS00171']
# ✔ Processed sequence 445 and saved progress.
# ✔ Found motifs for index 446: ['PS00941', 'PS00122']
# ✔ Processed sequence 446 and saved progress.
# ✔ Found motifs for index 447: ['PS50902', 'PS51384']
# ✔ Processed sequence 447 and saved progress.
# ⚠️ No motifs found for sequence at index 448. Skipping.
# ✔ Found motifs for index 449: ['PS00105']
# ✔ Processed sequence 449 and saved progress.
# ✔ Found motifs for index 450: ['PS00105']
# ✔ Processed sequence 450 and saved progress.
# ✔ Found motifs for index 451: ['PS00105']
# ✔ Processed sequence 451 and saved progress.
# ✔ Found motifs for index 452: ['PS00455', 'PS50075', 'PS00012']
# ✔ Processed sequence 452 and saved progress.
# ⚠️ No motifs found for sequence at index 453. Skipping.
# ✔ Found motifs for index 454: ['PS51420']
# ✔ Processed sequence 454 and saved progress.
# ✔ Found motifs for index 455: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 455 and saved progress.
# ✔ Found motifs for index 456: ['PS00091']
# ✔ Processed sequence 456 and saved progress.
# ✔ Found motifs for index 457: ['PS00677']
# ✔ Processed sequence 457 and saved progress.
# ✔ Found motifs for index 458: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 458 and saved progress.
# ✔ Found motifs for index 459: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 459 and saved progress.
# ✔ Found motifs for index 460: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 460 and saved progress.
# ✔ Found motifs for index 461: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 461 and saved progress.
# ✔ Found motifs for index 462: ['PS00123']
# ✔ Processed sequence 462 and saved progress.
# ✔ Found motifs for index 463: ['PS00123']
# ✔ Processed sequence 463 and saved progress.
# ✔ Found motifs for index 464: ['PS00113']
# ✔ Processed sequence 464 and saved progress.
# ✔ Found motifs for index 465: ['PS51278', 'PS00103']
# ✔ Processed sequence 465 and saved progress.
# ✔ Found motifs for index 466: ['PS50240', 'PS00134']
# ✔ Processed sequence 466 and saved progress.
# ✔ Found motifs for index 467: ['PS51330', 'PS00075']
# ✔ Processed sequence 467 and saved progress.
# ✔ Found motifs for index 468: ['PS00091']
# ✔ Processed sequence 468 and saved progress.
# ✔ Found motifs for index 469: ['PS50007']
# ✔ Processed sequence 469 and saved progress.
# ✔ Found motifs for index 470: ['PS51330', 'PS00075']
# ✔ Processed sequence 470 and saved progress.
# ✔ Found motifs for index 471: ['PS51007']
# ✔ Processed sequence 471 and saved progress.
# ✔ Found motifs for index 472: ['PS00076']
# ✔ Processed sequence 472 and saved progress.
# ✔ Found motifs for index 473: ['PS51007']
# ✔ Processed sequence 473 and saved progress.
# ✔ Found motifs for index 474: ['PS00296']
# ✔ Processed sequence 474 and saved progress.
# ✔ Found motifs for index 475: ['PS00365']
# ✔ Processed sequence 475 and saved progress.
# ✔ Found motifs for index 476: ['PS51007']
# ✔ Processed sequence 476 and saved progress.
# ⚠️ No motifs found for sequence at index 477. Skipping.
# ✔ Found motifs for index 478: ['PS00163']
# ✔ Processed sequence 478 and saved progress.
# ✔ Found motifs for index 479: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 479 and saved progress.
# ✔ Found motifs for index 480: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 480 and saved progress.
# ✔ Found motifs for index 481: ['PS00079', 'PS00080']
# ✔ Processed sequence 481 and saved progress.
# ✔ Found motifs for index 482: ['PS00088']
# ✔ Processed sequence 482 and saved progress.
# ✔ Found motifs for index 483: ['PS00088']
# ✔ Processed sequence 483 and saved progress.
# ✔ Found motifs for index 484: ['PS00275']
# ✔ Processed sequence 484 and saved progress.
# ✔ Found motifs for index 485: ['PS50011', 'PS00107', 'PS00108', 'PS51285']
# ✔ Processed sequence 485 and saved progress.
# ✔ Found motifs for index 486: ['PS50998', 'PS00011', 'PS01187', 'PS50026', 'PS00010', 'PS00022', 'PS01186', 'PS01186', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 486 and saved progress.
# ✔ Found motifs for index 487: ['PS01180', 'PS01187', 'PS00010', 'PS01186', 'PS01180', 'PS50923', 'PS50923', 'PS50240', 'PS00135']
# ✔ Processed sequence 487 and saved progress.
# ✔ Found motifs for index 488: ['PS51160', 'PS00150', 'PS00151']
# ✔ Processed sequence 488 and saved progress.
# ✔ Found motifs for index 489: ['PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 489 and saved progress.
# ✔ Found motifs for index 490: ['PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 490 and saved progress.
# ✔ Found motifs for index 491: ['PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 491 and saved progress.
# ✔ Found motifs for index 492: ['PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 492 and saved progress.
# ✔ Found motifs for index 493: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 493 and saved progress.
# ⚠️ No motifs found for sequence at index 494. Skipping.
# ⚠️ No motifs found for sequence at index 495. Skipping.
# ✔ Found motifs for index 496: ['PS00587']
# ✔ Processed sequence 496 and saved progress.
# ✔ Found motifs for index 497: ['PS50011', 'PS00107', 'PS00108']
# ✔ Processed sequence 497 and saved progress.
# ✔ Found motifs for index 498: ['PS00532']
# ✔ Processed sequence 498 and saved progress.
# ⚠️ No motifs found for sequence at index 499. Skipping.
# ✔ Found motifs for index 500: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 500 and saved progress.
# ✔ Found motifs for index 501: ['PS51318']
# ✔ Processed sequence 501 and saved progress.
# ✔ Found motifs for index 502: ['PS00110']
# ✔ Processed sequence 502 and saved progress.
# ⚠️ No motifs found for sequence at index 503. Skipping.
# ✔ Found motifs for index 504: ['PS00092']
# ✔ Processed sequence 504 and saved progress.
# ✔ Found motifs for index 505: ['PS00092']
# ✔ Processed sequence 505 and saved progress.
# ✔ Found motifs for index 506: ['PS00941', 'PS00122']
# ✔ Processed sequence 506 and saved progress.
# ⚠️ No motifs found for sequence at index 507. Skipping.
# ✔ Found motifs for index 508: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 508 and saved progress.
# ✔ Found motifs for index 509: ['PS00127']
# ✔ Processed sequence 509 and saved progress.
# ⚠️ No motifs found for sequence at index 510. Skipping.
# ✔ Found motifs for index 511: ['PS50404', 'PS50405']
# ...
# ✔ Processed sequence 910 and saved progress.
# ⚠️ No motifs found for sequence at index 911. Skipping.
# ⚠️ No motifs found for sequence at index 912. Skipping.
# ✔ Found motifs for index 913: ['PS00139', 'PS00639', 'PS00640']
# ✔ Processed sequence 913 and saved progress.
# ✔ Found motifs for index 914: ['PS50873', 'PS00436', 'PS00435']
# ✔ Processed sequence 914 and saved progress.
# ⚠️ No motifs found for sequence at index 915. Skipping.
# ⚠️ No motifs found for sequence at index 916. Skipping.
# ✔ Found motifs for index 917: ['PS00074']
# ✔ Processed sequence 917 and saved progress.
# ✔ Found motifs for index 918: ['PS50880', 'PS00177', 'PS52040']
# ✔ Processed sequence 918 and saved progress.
# ✔ Found motifs for index 919: ['PS00447']
# ✔ Processed sequence 919 and saved progress.
# ✔ Found motifs for index 920: ['PS51819', 'PS00934', 'PS00935']
# ✔ Processed sequence 920 and saved progress.
# ✔ Found motifs for index 921: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 921 and saved progress.
# ✔ Found motifs for index 922: ['PS00502']
# ✔ Processed sequence 922 and saved progress.
# ✔ Found motifs for index 923: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 923 and saved progress.
# ✔ Found motifs for index 924: ['PS00719', 'PS00608']
# ✔ Processed sequence 924 and saved progress.
# ✔ Found motifs for index 925: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 925 and saved progress.
# ✔ Found motifs for index 926: ['PS51600']
# ✔ Processed sequence 926 and saved progress.
# ✔ Found motifs for index 927: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 927 and saved progress.
# ⚠️ No motifs found for sequence at index 928. Skipping.
# ✔ Found motifs for index 929: ['PS51374', 'PS00469']
# ✔ Processed sequence 929 and saved progress.
# ✔ Found motifs for index 930: ['PS00061']
# ✔ Processed sequence 930 and saved progress.
# ✔ Found motifs for index 931: ['PS51415']
# ✔ Processed sequence 931 and saved progress.
# ✔ Found motifs for index 932: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 932 and saved progress.
# ✔ Found motifs for index 933: ['PS50968', 'PS00189', 'PS00076']
# ✔ Processed sequence 933 and saved progress.
# ✔ Found motifs for index 934: ['PS51348', 'PS00128']
# ✔ Processed sequence 934 and saved progress.
# ✔ Found motifs for index 935: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 935 and saved progress.
# ✔ Found motifs for index 936: ['PS00441']
# ✔ Processed sequence 936 and saved progress.
# ✔ Found motifs for index 937: ['PS50011', 'PS00107', 'PS00108']
# ✔ Processed sequence 937 and saved progress.
# ✔ Found motifs for index 938: ['PS50011', 'PS00107', 'PS00108']
# ✔ Processed sequence 938 and saved progress.
# ✔ Found motifs for index 939: ['PS00687', 'PS00070']
# ✔ Processed sequence 939 and saved progress.
# ✔ Found motifs for index 940: ['PS51733']
# ✔ Processed sequence 940 and saved progress.
# ✔ Found motifs for index 941: ['PS51733']
# ✔ Processed sequence 941 and saved progress.
# ✔ Found motifs for index 942: ['PS51144', 'PS00162']
# ✔ Processed sequence 942 and saved progress.
# ✔ Found motifs for index 943: ['PS00091']
# ✔ Processed sequence 943 and saved progress.
# ✔ Found motifs for index 944: ['PS00175']
# ✔ Processed sequence 944 and saved progress.
# ✔ Found motifs for index 945: ['PS51257', 'PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 945 and saved progress.
# ✔ Found motifs for index 946: ['PS51257', 'PS51767', 'PS00141', 'PS00141']
# ✔ Processed sequence 946 and saved progress.
# ✔ Found motifs for index 947: ['PS51257', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 947 and saved progress.
# ✔ Found motifs for index 948: ['PS00368']
# ✔ Processed sequence 948 and saved progress.
# ⚠️ No motifs found for sequence at index 949. Skipping.
# ✔ Found motifs for index 950: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 950 and saved progress.
# ✔ Found motifs for index 951: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 951 and saved progress.
# ✔ Found motifs for index 952: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 952 and saved progress.
# ✔ Found motifs for index 953: ['PS00546', 'PS00142', 'PS51642', 'PS00024', 'PS51642', 'PS51642', 'PS51642']
# ✔ Processed sequence 953 and saved progress.
# ✔ Found motifs for index 954: ['PS51435', 'PS00726', 'PS00727', 'PS00728']
# ✔ Processed sequence 954 and saved progress.
# ✔ Found motifs for index 955: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 955 and saved progress.
# ✔ Found motifs for index 956: ['PS00096']
# ✔ Processed sequence 956 and saved progress.
# ✔ Found motifs for index 957: ['PS00436', 'PS50873', 'PS00435']
# ✔ Processed sequence 957 and saved progress.
# ✔ Found motifs for index 958: ['PS00091']
# ✔ Processed sequence 958 and saved progress.
# ⚠️ No motifs found for sequence at index 959. Skipping.
# ✔ Found motifs for index 960: ['PS00118', 'PS00119']
# ✔ Processed sequence 960 and saved progress.
# ✔ Found motifs for index 961: ['PS51441', 'PS51384']
# ✔ Processed sequence 961 and saved progress.
# ✔ Found motifs for index 962: ['PS00595']
# ✔ Processed sequence 962 and saved progress.
# ✔ Found motifs for index 963: ['PS00595']
# ✔ Processed sequence 963 and saved progress.
# ⚠️ No motifs found for sequence at index 964. Skipping.
# ✔ Found motifs for index 965: ['PS51892', 'PS00136', 'PS00137', 'PS00138']
# ✔ Processed sequence 965 and saved progress.
# ✔ Found motifs for index 966: ['PS50880', 'PS00177', 'PS52040']
# ✔ Processed sequence 966 and saved progress.
# ✔ Found motifs for index 967: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 967 and saved progress.
# ✔ Found motifs for index 968: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 968 and saved progress.
# ✔ Found motifs for index 969: ['PS00105']
# ✔ Processed sequence 969 and saved progress.
# ✔ Found motifs for index 970: ['PS51352', 'PS00194', 'PS51352', 'PS00194', 'PS00014']
# ✔ Processed sequence 970 and saved progress.
# ✔ Found motifs for index 971: ['PS00185', 'PS51471', 'PS00186']
# ✔ Processed sequence 971 and saved progress.
# ✔ Found motifs for index 972: ['PS51761', 'PS00776', 'PS00777']
# ✔ Processed sequence 972 and saved progress.
# ✔ Found motifs for index 973: ['PS00124']
# ✔ Processed sequence 973 and saved progress.
# ✔ Found motifs for index 974: ['PS00530', 'PS00531']
# ✔ Processed sequence 974 and saved progress.
# ✔ Found motifs for index 975: ['PS00118', 'PS00119']
# ✔ Processed sequence 975 and saved progress.
# ✔ Found motifs for index 976: ['PS50215', 'PS00142', 'PS50214']
# ✔ Processed sequence 976 and saved progress.
# ✔ Found motifs for index 977: ['PS51421']
# ✔ Processed sequence 977 and saved progress.
# ✔ Found motifs for index 978: ['PS50059']
# ✔ Processed sequence 978 and saved progress.
# ✔ Found motifs for index 979: ['PS00105']
# ✔ Processed sequence 979 and saved progress.
# ⚠️ No motifs found for sequence at index 980. Skipping.
# ✔ Found motifs for index 981: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 981 and saved progress.
# ✔ Found motifs for index 982: ['PS50002', 'PS50001', 'PS50011', 'PS00107', 'PS00109']
# ✔ Processed sequence 982 and saved progress.
# ✔ Found motifs for index 983: ['PS00091']
# ✔ Processed sequence 983 and saved progress.
# ✔ Found motifs for index 984: ['PS00091']
# ✔ Processed sequence 984 and saved progress.
# ✔ Found motifs for index 985: ['PS00167']
# ✔ Processed sequence 985 and saved progress.
# ⚠️ No motifs found for sequence at index 986. Skipping.
# ✔ Found motifs for index 987: ['PS50011', 'PS00107', 'PS00108', 'PS51285']
# ✔ Processed sequence 987 and saved progress.
# ✔ Found motifs for index 988: ['PS51612']
# ✔ Processed sequence 988 and saved progress.
# ✔ Found motifs for index 989: ['PS50158', 'PS50158', 'PS50175', 'PS00141', 'PS50878', 'PS50879', 'PS50876', 'PS50994', 'PS51027']
# ✔ Processed sequence 989 and saved progress.
# ✔ Found motifs for index 990: ['PS50059']
# ✔ Processed sequence 990 and saved progress.
# ✔ Found motifs for index 991: ['PS00470']
# ✔ Processed sequence 991 and saved progress.
# ✔ Found motifs for index 992: ['PS50011', 'PS00107', 'PS01351']
# ✔ Processed sequence 992 and saved progress.
# ✔ Found motifs for index 993: ['PS50011', 'PS00107', 'PS01351']
# ✔ Processed sequence 993 and saved progress.
# ✔ Found motifs for index 994: ['PS51007']
# ✔ Processed sequence 994 and saved progress.
# ✔ Found motifs for index 995: ['PS51257', 'PS00146']
# ✔ Processed sequence 995 and saved progress.
# ✔ Found motifs for index 996: ['PS51101']
# ✔ Processed sequence 996 and saved progress.
# ✔ Found motifs for index 997: ['PS51257', 'PS00146']
# ✔ Processed sequence 997 and saved progress.
# ⚠️ No motifs found for sequence at index 998. Skipping.
# ✔ Found motifs for index 999: ['PS50002', 'PS50001', 'PS50011', 'PS00107']
# ✔ Processed sequence 999 and saved progress.
# ✔ Found motifs for index 1000: ['PS50002', 'PS50001', 'PS50011', 'PS00107']
# ✔ Processed sequence 1000 and saved progress.
# ✔ Found motifs for index 1001: ['PS00631']
# ✔ Processed sequence 1001 and saved progress.
# ✔ Found motifs for index 1002: ['PS51257', 'PS00146']
# ✔ Processed sequence 1002 and saved progress.
# ✔ Found motifs for index 1003: ['PS51257', 'PS00336']
# ✔ Processed sequence 1003 and saved progress.
# ✔ Found motifs for index 1004: ['PS50011', 'PS00107', 'PS00108']
# ✔ Processed sequence 1004 and saved progress.
# ✔ Found motifs for index 1005: ['PS00185', 'PS51471', 'PS00186']
# ✔ Processed sequence 1005 and saved progress.
# ✔ Found motifs for index 1006: ['PS00546', 'PS00142', 'PS51642', 'PS00024', 'PS51642', 'PS51642', 'PS51642']
# ✔ Processed sequence 1006 and saved progress.
# ✔ Found motifs for index 1007: ['PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 1007 and saved progress.
# ✔ Found motifs for index 1008: ['PS00743', 'PS00744']
# ✔ Processed sequence 1008 and saved progress.
# ✔ Found motifs for index 1009: ['PS00068']
# ✔ Processed sequence 1009 and saved progress.
# ✔ Found motifs for index 1010: ['PS50011', 'PS00107', 'PS01351']
# ✔ Processed sequence 1010 and saved progress.
# ✔ Found motifs for index 1011: ['PS50948', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 1011 and saved progress.
# ✔ Found motifs for index 1012: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 1012 and saved progress.
# ✔ Found motifs for index 1013: ['PS50998', 'PS00011', 'PS50070', 'PS00021', 'PS50070', 'PS00021', 'PS50240', 'PS00134', 'PS00135']
# ✔ Processed sequence 1013 and saved progress.
# ✔ Found motifs for index 1014: ['PS50209', 'PS00455', 'PS50208', 'PS01121', 'PS01122', 'PS50207']
# ✔ Processed sequence 1014 and saved progress.
# ✔ Found motifs for index 1015: ['PS50970', 'PS50972', 'PS51337', 'PS51332', 'PS50974']
# ✔ Processed sequence 1015 and saved progress.
# ✔ Found motifs for index 1016: ['PS51144', 'PS00162']
# ✔ Processed sequence 1016 and saved progress.
# ✔ Found motifs for index 1017: ['PS51144', 'PS00162']
# ✔ Processed sequence 1017 and saved progress.
# ✔ Found motifs for index 1018: ['PS51144', 'PS00162']
# ✔ Processed sequence 1018 and saved progress.
# ✔ Found motifs for index 1019: ['PS01202']
# ✔ Processed sequence 1019 and saved progress.
# ⚠️ No motifs found for sequence at index 1020. Skipping.
# ⚠️ No motifs found for sequence at index 1021. Skipping.
# ⚠️ No motifs found for sequence at index 1022. Skipping.
# ✔ Found motifs for index 1023: ['PS50979', 'PS50975', 'PS00866', 'PS00867']
# ✔ Processed sequence 1023 and saved progress.
# ⚠️ No motifs found for sequence at index 1024. Skipping.
# ✔ Found motifs for index 1025: ['PS51144', 'PS00162']
# ✔ Processed sequence 1025 and saved progress.
# ✔ Found motifs for index 1026: ['PS51144', 'PS00162']
# ✔ Processed sequence 1026 and saved progress.
# ✔ Found motifs for index 1027: ['PS00522']
# ✔ Processed sequence 1027 and saved progress.
# ✔ Found motifs for index 1028: ['PS00522']
# ✔ Processed sequence 1028 and saved progress.
# ✔ Found motifs for index 1029: ['PS51144', 'PS00162']
# ✔ Processed sequence 1029 and saved progress.
# ✔ Found motifs for index 1030: ['PS51144', 'PS00162']
# ✔ Processed sequence 1030 and saved progress.
# ✔ Found motifs for index 1031: ['PS51144', 'PS00162']
# ✔ Processed sequence 1031 and saved progress.
# ✔ Found motifs for index 1032: ['PS51144', 'PS00162']
# ✔ Processed sequence 1032 and saved progress.
# ✔ Found motifs for index 1033: ['PS51144', 'PS00162']
# ✔ Processed sequence 1033 and saved progress.
# ✔ Found motifs for index 1034: ['PS51455']
# ✔ Processed sequence 1034 and saved progress.
# ✔ Found motifs for index 1035: ['PS00933', 'PS00445']
# ✔ Processed sequence 1035 and saved progress.
# ⚠️ No motifs found for sequence at index 1036. Skipping.
# ✔ Found motifs for index 1037: ['PS00091']
# ✔ Processed sequence 1037 and saved progress.
# ✔ Found motifs for index 1038: ['PS00091']
# ✔ Processed sequence 1038 and saved progress.
# ✔ Found motifs for index 1039: ['PS01202']
# ✔ Processed sequence 1039 and saved progress.
# ✔ Found motifs for index 1040: ['PS51186']
# ✔ Processed sequence 1040 and saved progress.
# ✔ Found motifs for index 1041: ['PS50206', 'PS00380', 'PS50206', 'PS00683']
# ✔ Processed sequence 1041 and saved progress.
# ✔ Found motifs for index 1042: ['PS50206', 'PS00380', 'PS50206', 'PS00683']
# ✔ Processed sequence 1042 and saved progress.
# ✔ Found motifs for index 1043: ['PS51257', 'PS00530', 'PS00531']
# ✔ Processed sequence 1043 and saved progress.
# ✔ Found motifs for index 1044: ['PS00093']
# ✔ Processed sequence 1044 and saved progress.
# ✔ Found motifs for index 1045: ['PS51257', 'PS00134', 'PS00135']
# ✔ Processed sequence 1045 and saved progress.
# ✔ Found motifs for index 1046: ['PS00933', 'PS00445']
# ✔ Processed sequence 1046 and saved progress.
# ⚠️ No motifs found for sequence at index 1047. Skipping.
# ⚠️ No motifs found for sequence at index 1048. Skipping.
# ✔ Found motifs for index 1049: ['PS51330', 'PS00075']
# ✔ Processed sequence 1049 and saved progress.
# ✔ Found motifs for index 1050: ['PS00091']
# ✔ Processed sequence 1050 and saved progress.
# ✔ Found motifs for index 1051: ['PS00118', 'PS00119']
# ✔ Processed sequence 1051 and saved progress.
# ✔ Found motifs for index 1052: ['PS00139', 'PS00639', 'PS00640']
# ✔ Processed sequence 1052 and saved progress.
# ✔ Found motifs for index 1053: ['PS00091']
# ✔ Processed sequence 1053 and saved progress.
# ✔ Found motifs for index 1054: ['PS00522']
# ✔ Processed sequence 1054 and saved progress.
# ✔ Found motifs for index 1055: ['PS00522']
# ✔ Processed sequence 1055 and saved progress.
# ✔ Found motifs for index 1056: ['PS00522']
# ✔ Processed sequence 1056 and saved progress.
# ✔ Found motifs for index 1057: ['PS00091']
# ✔ Processed sequence 1057 and saved progress.
# ⚠️ No motifs found for sequence at index 1058. Skipping.
# ✔ Found motifs for index 1059: ['PS00631']
# ✔ Processed sequence 1059 and saved progress.
# ✔ Found motifs for index 1060: ['PS00631']
# ✔ Processed sequence 1060 and saved progress.
# ✔ Found motifs for index 1061: ['PS00118', 'PS00119']
# ✔ Processed sequence 1061 and saved progress.
# ⚠️ Failed to retrieve motifs for sequence (Error 414)
# ⚠️ No motifs found for sequence at index 1062. Skipping.
# ✔ Found motifs for index 1064: ['PS00687', 'PS00070']
# ✔ Processed sequence 1064 and saved progress.
# ✔ Found motifs for index 1065: ['PS00522']
# ✔ Processed sequence 1065 and saved progress.
# ✔ Found motifs for index 1066: ['PS00522']
# ✔ Processed sequence 1066 and saved progress.
# ✔ Found motifs for index 1067: ['PS00522']
# ✔ Processed sequence 1067 and saved progress.
# ✔ Found motifs for index 1068: ['PS00091']
# ✔ Processed sequence 1068 and saved progress.
# ✔ Found motifs for index 1069: ['PS00091']
# ✔ Processed sequence 1069 and saved progress.

# %%
import pandas as pd

# ✅ Define file path
partial_file = "/Users/carmenshero/Desktop/Datasets/Partial_Training.csv"

# ✅ Load dataset
df_partial = pd.read_csv(partial_file, dtype={"ec_numbers": str, "sequence": str}, low_memory=False)

# ✅ Ensure "Processed_Motifs" column exists
if "Processed_Motifs" not in df_partial.columns:
    df_partial["Processed_Motifs"] = False  # Create column if missing
else:
    df_partial["Processed_Motifs"] = False  # Reset all values to False

# ✅ Save updated dataset
df_partial.to_csv(partial_file, index=False)

print("✔ Reset all values in 'Processed_Motifs' to False.")
# Out:
# ✔ Reset all values in 'Processed_Motifs' to False.

# %%
# ✅ Step 1: Collect all unique motifs across Partial_Training.csv
all_unique_motifs = set()

for index, row in df_partial.iterrows():
    sequence = row["sequence"]  # ✅ Use sequence instead of UniProt ID
    
    # ✅ Skip rows that are already processed
    if row["Processed_Motifs"]:
        continue
    
    motifs = get_protein_motifs(sequence)  # ✅ Query motifs based on sequence
    all_unique_motifs.update(motifs)

# ✅ Convert motifs into a sorted list for consistency
all_unique_motifs = sorted(list(all_unique_motifs))

# ✅ Step 2: Add new motif columns to the DataFrame (initialize to 0)
for motif in all_unique_motifs:
    if motif not in df_partial.columns:
        df_partial[motif] = 0  # Default to zero (absence of motif)

# ✅ Save updated Partial_Training.csv
df_partial.to_csv(partial_file, index=False)
print(f"✔ Extracted {len(all_unique_motifs)} unique motifs. Added missing columns and saved dataset.")
